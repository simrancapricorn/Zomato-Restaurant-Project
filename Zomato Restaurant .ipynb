# %% [markdown]
# # Zomato Restaurant Project

# %% [markdown]
# # Problem Statement:

# %% [markdown]
# Zomato Data Analysis is one of the most useful analysis for foodies who want to taste the best
# cuisines of every part of the world which lies in their budget. This analysis is also for those who
# want to find the value for money restaurants in various parts of the country for the cuisines.
# Additionally, this analysis caters the needs of people who are striving to get the best cuisine of
# the country and which locality of that country serves that cuisines with maximum number of
# restaurants.

# %% [markdown]
# # Data Storage:

# %% [markdown]
# This problem statement contains two datasets- Zomato.csv and country_code.csv.
# Country_code.csv contains two variables:
#
#  Country code
#
#  Country name
#
# The collected data has been stored in the Comma Separated Value file Zomato.csv. Each
# restaurant in the dataset is uniquely identified by its Restaurant Id. Every Restaurant contains the
# following variables:
#
# • Restaurant Id: Unique id of every restaurant across various cities of the world
#
# • Restaurant Name: Name of the restaurant
#
# • Country Code: Country in which restaurant is located
#
# • City: City in which restaurant is located
#
# • Address: Address of the restaurant
#
# • Locality: Location in the city
#
# • Locality Verbose: Detailed description of the locality
#
# • Longitude: Longitude coordinate of the restaurant&#39;s location
#
# • Latitude: Latitude coordinate of the restaurant&#39;s location
#
# • Cuisines: Cuisines offered by the restaurant
#
# • Average Cost for two: Cost for two people in different currencies ��
#
# • Currency: Currency of the country
#
# • Has Table booking: yes/no
#
# • Has Online delivery: yes/ no
#
# • Is delivering: yes/ no
#
# • Switch to order menu: yes/no
#
# • Price range: range of price of food
#
# • Aggregate Rating: Average rating out of 5
#
# • Rating color: depending upon the average rating color
#
# • Rating text: text on the basis of rating of rating
#
# • Votes: Number of ratings casted by people
#
# Problem statement : In this dataset predict 2 things –
#
# 1) Average Cost for two
#
# 2) Price range

# %% [markdown]
# # Importing necessary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing dataset

# %%
# reading the data
df1 = pd.read_csv('Zomato Restaurant',encoding='latin-1')

# %%
df1
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208     ï¿½ï¿½stanbul
# 9547        5908749         Ceviz Aï¿½ï¿½acÛ±           208     ï¿½ï¿½stanbul
# 9548        5915807                     Huqqa           208     ï¿½ï¿½stanbul
# 9549        5916112         Aï¿½ï¿½ï¿½k Kahve           208     ï¿½ï¿½stanbul
# 9550        5927402  Walter's Coffee Roastery           208     ï¿½ï¿½stanbul
#
#                                                 Address  \
# 0     Third Floor, Century City Mall, Kalayaan Avenu...
# 1     Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2     Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3     Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4     Third Floor, Mega Atrium, SM Megamall, Ortigas...
# ...                                                 ...
# 9546  Kemankeï¿½ï¿½ Karamustafa Paï¿½ï¿½a Mahallesi,...
# 9547  Koï¿½ï¿½uyolu Mahallesi, Muhittin ï¿½ï¿½stï¿½_...
# 9548  Kuruï¿½_eï¿½ï¿½me Mahallesi, Muallim Naci Cadd...
# 9549  Kuruï¿½_eï¿½ï¿½me Mahallesi, Muallim Naci Cadd...
# 9550  Cafeaï¿½ï¿½a Mahallesi, BademaltÛ± Sokak, No 2...
#
#                                         Locality  \
# 0      Century City Mall, Poblacion, Makati City
# 1     Little Tokyo, Legaspi Village, Makati City
# 2     Edsa Shangri-La, Ortigas, Mandaluyong City
# 3         SM Megamall, Ortigas, Mandaluyong City
# 4         SM Megamall, Ortigas, Mandaluyong City
# ...                                          ...
# 9546                                  Karakï¿½_y
# 9547                               Koï¿½ï¿½uyolu
# 9548                           Kuruï¿½_eï¿½ï¿½me
# 9549                           Kuruï¿½_eï¿½ï¿½me
# 9550                                        Moda
#
#                                        Locality Verbose   Longitude  \
# 0     Century City Mall, Poblacion, Makati City, Mak...  121.027535
# 1     Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101
# 2     Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831
# 3     SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475
# 4     SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508
# ...                                                 ...         ...
# 9546                          Karakï¿½_y, ï¿½ï¿½stanbul   28.977392
# 9547                       Koï¿½ï¿½uyolu, ï¿½ï¿½stanbul   29.041297
# 9548                   Kuruï¿½_eï¿½ï¿½me, ï¿½ï¿½stanbul   29.034640
# 9549                   Kuruï¿½_eï¿½ï¿½me, ï¿½ï¿½stanbul   29.036019
# 9550                                Moda, ï¿½ï¿½stanbul   29.026016
#
#        Latitude                          Cuisines  ...          Currency  \
# 0     14.565443        French, Japanese, Desserts  ...  Botswana Pula(P)
# 1     14.553708                          Japanese  ...  Botswana Pula(P)
# 2     14.581404  Seafood, Asian, Filipino, Indian  ...  Botswana Pula(P)
# 3     14.585318                   Japanese, Sushi  ...  Botswana Pula(P)
# 4     14.584450                  Japanese, Korean  ...  Botswana Pula(P)
# ...         ...                               ...  ...               ...
# 9546  41.022793                           Turkish  ...  Turkish Lira(TL)
# 9547  41.009847   World Cuisine, Patisserie, Cafe  ...  Turkish Lira(TL)
# 9548  41.055817            Italian, World Cuisine  ...  Turkish Lira(TL)
# 9549  41.057979                   Restaurant Cafe  ...  Turkish Lira(TL)
# 9550  40.984776                              Cafe  ...  Turkish Lira(TL)
#
#      Has Table booking Has Online delivery Is delivering now  \
# 0                  Yes                  No                No
# 1                  Yes                  No                No
# 2                  Yes                  No                No
# 3                   No                  No                No
# 4                  Yes                  No                No
# ...                ...                 ...               ...
# 9546                No                  No                No
# 9547                No                  No                No
# 9548                No                  No                No
# 9549                No                  No                No
# 9550                No                  No                No
#
#      Switch to order menu Price range  Aggregate rating  Rating color  \
# 0                      No           3               4.8    Dark Green
# 1                      No           3               4.5    Dark Green
# 2                      No           4               4.4         Green
# 3                      No           4               4.9    Dark Green
# 4                      No           4               4.8    Dark Green
# ...                   ...         ...               ...           ...
# 9546                   No           3               4.1         Green
# 9547                   No           3               4.2         Green
# 9548                   No           4               3.7        Yellow
# 9549                   No           4               4.0         Green
# 9550                   No           2               4.0         Green
#
#      Rating text Votes
# 0      Excellent   314
# 1      Excellent   591
# 2      Very Good   270
# 3      Excellent   365
# 4      Excellent   229
# ...          ...   ...
# 9546   Very Good   788
# 9547   Very Good  1034
# 9548        Good   661
# 9549   Very Good   901
# 9550   Very Good   591
#
# [9551 rows x 21 columns]

# %% [markdown]
# Here we have 9551 rows and 21 columns in the dataset

# %%
df1.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# 3      SM Megamall, Ortigas, Mandaluyong City
# 4      SM Megamall, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831  14.581404
# 3  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475  14.585318
# 4  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508  14.584450
#
#                            Cuisines  ...          Currency Has Table booking  \
# 0        French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
# 1                          Japanese  ...  Botswana Pula(P)               Yes
# 2  Seafood, Asian, Filipino, Indian  ...  Botswana Pula(P)               Yes
# 3                   Japanese, Sushi  ...  Botswana Pula(P)                No
# 4                  Japanese, Korean  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
# 1                  No                No                   No           3
# 2                  No                No                   No           4
# 3                  No                No                   No           4
# 4                  No                No                   No           4
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
# 1               4.5    Dark Green   Excellent   591
# 2               4.4         Green   Very Good   270
# 3               4.9    Dark Green   Excellent   365
# 4               4.8    Dark Green   Excellent   229
#
# [5 rows x 21 columns]

# %%
df1.tail()
# Out:
#       Restaurant ID           Restaurant Name  Country Code           City  \
# 9546        5915730              NamlÛ± Gurme           208  ï¿½ï¿½stanbul
# 9547        5908749         Ceviz Aï¿½ï¿½acÛ±           208  ï¿½ï¿½stanbul
# 9548        5915807                     Huqqa           208  ï¿½ï¿½stanbul
# 9549        5916112         Aï¿½ï¿½ï¿½k Kahve           208  ï¿½ï¿½stanbul
# 9550        5927402  Walter's Coffee Roastery           208  ï¿½ï¿½stanbul
#
#                                                 Address           Locality  \
# 9546  Kemankeï¿½ï¿½ Karamustafa Paï¿½ï¿½a Mahallesi,...         Karakï¿½_y
# 9547  Koï¿½ï¿½uyolu Mahallesi, Muhittin ï¿½ï¿½stï¿½_...      Koï¿½ï¿½uyolu
# 9548  Kuruï¿½_eï¿½ï¿½me Mahallesi, Muallim Naci Cadd...  Kuruï¿½_eï¿½ï¿½me
# 9549  Kuruï¿½_eï¿½ï¿½me Mahallesi, Muallim Naci Cadd...  Kuruï¿½_eï¿½ï¿½me
# 9550  Cafeaï¿½ï¿½a Mahallesi, BademaltÛ± Sokak, No 2...               Moda
#
#                       Locality Verbose  Longitude   Latitude  \
# 9546         Karakï¿½_y, ï¿½ï¿½stanbul  28.977392  41.022793
# 9547      Koï¿½ï¿½uyolu, ï¿½ï¿½stanbul  29.041297  41.009847
# 9548  Kuruï¿½_eï¿½ï¿½me, ï¿½ï¿½stanbul  29.034640  41.055817
# 9549  Kuruï¿½_eï¿½ï¿½me, ï¿½ï¿½stanbul  29.036019  41.057979
# 9550               Moda, ï¿½ï¿½stanbul  29.026016  40.984776
#
#                              Cuisines  ...          Currency  \
# 9546                          Turkish  ...  Turkish Lira(TL)
# 9547  World Cuisine, Patisserie, Cafe  ...  Turkish Lira(TL)
# 9548           Italian, World Cuisine  ...  Turkish Lira(TL)
# 9549                  Restaurant Cafe  ...  Turkish Lira(TL)
# 9550                             Cafe  ...  Turkish Lira(TL)
#
#      Has Table booking Has Online delivery Is delivering now  \
# 9546                No                  No                No
# 9547                No                  No                No
# 9548                No                  No                No
# 9549                No                  No                No
# 9550                No                  No                No
#
#      Switch to order menu Price range  Aggregate rating  Rating color  \
# 9546                   No           3               4.1         Green
# 9547                   No           3               4.2         Green
# 9548                   No           4               3.7        Yellow
# 9549                   No           4               4.0         Green
# 9550                   No           2               4.0         Green
#
#      Rating text Votes
# 9546   Very Good   788
# 9547   Very Good  1034
# 9548        Good   661
# 9549   Very Good   901
# 9550   Very Good   591
#
# [5 rows x 21 columns]

# %%
df1.sample()
# Out:
#       Restaurant ID                  Restaurant Name  Country Code       City  \
# 3852       18124389  Mahesh Shudh Vaishno Bhojanalya             1  New Delhi
#
#                                                 Address   Locality  \
# 3852  Near GTB Metro Station, Delhi University, GTB ...  GTB Nagar
#
#           Locality Verbose  Longitude  Latitude      Cuisines  ...  \
# 3852  GTB Nagar, New Delhi  77.205081  28.69793  North Indian  ...
#
#                 Currency Has Table booking Has Online delivery  \
# 3852  Indian Rupees(Rs.)                No                  No
#
#      Is delivering now Switch to order menu Price range  Aggregate rating  \
# 3852                No                   No           1               0.0
#
#       Rating color Rating text Votes
# 3852         White   Not rated     0
#
# [1 rows x 21 columns]

# %%
df1.shape
# Out:
# (9551, 21)

# %% [markdown]
# This is the shape of the above dataset.

# %%
df_country = pd.read_excel(r"C:\Users\simran\Downloads\Country-Code.xlsx")
df_country
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %% [markdown]
# These are the country with the country code

# %%
df_country.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
df_country.tail()
# Out:
#     Country Code         Country
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
df_country.sample()
# Out:
#    Country Code Country
# 3            37  Canada

# %%
df_country.shape
# Out:
# (15, 2)

# %% [markdown]
# # Now Lets Merge both the dataset

# %%
data=pd.merge(df1,df_country,on='Country Code',how='left')

# %%
data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# 3      SM Megamall, Ortigas, Mandaluyong City
# 4      SM Megamall, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831  14.581404
# 3  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475  14.585318
# 4  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508  14.584450
#
#                            Cuisines  ...  Has Table booking  \
# 0        French, Japanese, Desserts  ...                Yes
# 1                          Japanese  ...                Yes
# 2  Seafood, Asian, Filipino, Indian  ...                Yes
# 3                   Japanese, Sushi  ...                 No
# 4                  Japanese, Korean  ...                Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
# 1                  No                No                   No           3
# 2                  No                No                   No           4
# 3                  No                No                   No           4
# 4                  No                No                   No           4
#
#   Aggregate rating  Rating color  Rating text Votes      Country
# 0              4.8    Dark Green    Excellent   314  Phillipines
# 1              4.5    Dark Green    Excellent   591  Phillipines
# 2              4.4         Green    Very Good   270  Phillipines
# 3              4.9    Dark Green    Excellent   365  Phillipines
# 4              4.8    Dark Green    Excellent   229  Phillipines
#
# [5 rows x 22 columns]

# %% [markdown]
# Here we have Merged both of the dataset

# %%
data.shape
# Out:
# (9551, 22)

# %%
data.tail()
# Out:
#       Restaurant ID           Restaurant Name  Country Code           City  \
# 9546        5915730              NamlÛ± Gurme           208  ï¿½ï¿½stanbul
# 9547        5908749         Ceviz Aï¿½ï¿½acÛ±           208  ï¿½ï¿½stanbul
# 9548        5915807                     Huqqa           208  ï¿½ï¿½stanbul
# 9549        5916112         Aï¿½ï¿½ï¿½k Kahve           208  ï¿½ï¿½stanbul
# 9550        5927402  Walter's Coffee Roastery           208  ï¿½ï¿½stanbul
#
#                                                 Address           Locality  \
# 9546  Kemankeï¿½ï¿½ Karamustafa Paï¿½ï¿½a Mahallesi,...         Karakï¿½_y
# 9547  Koï¿½ï¿½uyolu Mahallesi, Muhittin ï¿½ï¿½stï¿½_...      Koï¿½ï¿½uyolu
# 9548  Kuruï¿½_eï¿½ï¿½me Mahallesi, Muallim Naci Cadd...  Kuruï¿½_eï¿½ï¿½me
# 9549  Kuruï¿½_eï¿½ï¿½me Mahallesi, Muallim Naci Cadd...  Kuruï¿½_eï¿½ï¿½me
# 9550  Cafeaï¿½ï¿½a Mahallesi, BademaltÛ± Sokak, No 2...               Moda
#
#                       Locality Verbose  Longitude   Latitude  \
# 9546         Karakï¿½_y, ï¿½ï¿½stanbul  28.977392  41.022793
# 9547      Koï¿½ï¿½uyolu, ï¿½ï¿½stanbul  29.041297  41.009847
# 9548  Kuruï¿½_eï¿½ï¿½me, ï¿½ï¿½stanbul  29.034640  41.055817
# 9549  Kuruï¿½_eï¿½ï¿½me, ï¿½ï¿½stanbul  29.036019  41.057979
# 9550               Moda, ï¿½ï¿½stanbul  29.026016  40.984776
#
#                              Cuisines  ...  Has Table booking  \
# 9546                          Turkish  ...                 No
# 9547  World Cuisine, Patisserie, Cafe  ...                 No
# 9548           Italian, World Cuisine  ...                 No
# 9549                  Restaurant Cafe  ...                 No
# 9550                             Cafe  ...                 No
#
#      Has Online delivery Is delivering now Switch to order menu Price range  \
# 9546                  No                No                   No           3
# 9547                  No                No                   No           3
# 9548                  No                No                   No           4
# 9549                  No                No                   No           4
# 9550                  No                No                   No           2
#
#      Aggregate rating  Rating color  Rating text Votes Country
# 9546              4.1         Green    Very Good   788  Turkey
# 9547              4.2         Green    Very Good  1034  Turkey
# 9548              3.7        Yellow         Good   661  Turkey
# 9549              4.0         Green    Very Good   901  Turkey
# 9550              4.0         Green    Very Good   591  Turkey
#
# [5 rows x 22 columns]

# %%
data.sample(5)
# Out:
#       Restaurant ID      Restaurant Name  Country Code       City  \
# 7087           2786         Punjab Grill             1  New Delhi
# 2748         306841       Bablu Chic Inn             1  New Delhi
# 4939       18472702  The Chinese Kitchen             1  New Delhi
# 7780       18342098      Chef's Paradise             1  New Delhi
# 1435         302455       Mediumwelldone             1    Gurgaon
#
#                                                 Address  \
# 7087  2nd Floor, Food Court, Select Citywalk Mall, S...
# 2748  Shop 9, Pocket B, DDA Market, Ashok Vihar Phas...
# 4939  F-11, Shop 10, Vijay Chowk, Laxmi Nagar, New D...
# 7780  B 75, New Ashok Nagar, Vasundhara Enclave, New...
# 1435  LG-34, DLF South Point Mall, Golf Course Road,...
#
#                                     Locality  \
# 7087             Select Citywalk Mall, Saket
# 2748                     Ashok Vihar Phase 3
# 4939                             Laxmi Nagar
# 7780                      Vasundhara Enclave
# 1435  DLF South Point Mall, Golf Course Road
#
#                                      Locality Verbose  Longitude   Latitude  \
# 7087           Select Citywalk Mall, Saket, New Delhi  77.219328  28.528695
# 2748                   Ashok Vihar Phase 3, New Delhi  77.178049  28.692485
# 4939                           Laxmi Nagar, New Delhi   0.000000   0.000000
# 7780                    Vasundhara Enclave, New Delhi  77.306500  28.591545
# 1435  DLF South Point Mall, Golf Course Road, Gurgaon  77.099478  28.447652
#
#                               Cuisines  ...  Has Table booking  \
# 7087             North Indian, Mughlai  ...                Yes
# 2748             Mughlai, North Indian  ...                 No
# 4939                           Chinese  ...                 No
# 7780    North Indian, Mughlai, Chinese  ...                 No
# 1435  American, European, North Indian  ...                Yes
#
#      Has Online delivery Is delivering now Switch to order menu Price range  \
# 7087                 Yes                No                   No           3
# 2748                  No                No                   No           2
# 4939                  No                No                   No           1
# 7780                 Yes                No                   No           1
# 1435                 Yes                No                   No           3
#
#      Aggregate rating  Rating color  Rating text Votes Country
# 7087              4.2         Green    Very Good  1971   India
# 2748              3.6        Yellow         Good    34   India
# 4939              3.1        Orange      Average     7   India
# 7780              3.1        Orange      Average    36   India
# 1435              3.5        Yellow         Good   259   India
#
# [5 rows x 22 columns]

# %% [markdown]
# I have Shuffled the dataset but still i have not found any NaN value ,so Now we will check it through isnull() and see it there are any NaN value present

# %%
data.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %% [markdown]
# Here my target variable will be Average Cost for two

# %%
# Now lets identify which types of data types do they all belongs

data.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %% [markdown]
# Aggregate rating is in float64 which makes it a Regression problem.. Rest we have columns in int64 and object type too

# %% [markdown]
# # Droping Duplicates

# %%
data.drop_duplicates()
data.shape
# Out:
# (9551, 22)

# %% [markdown]
# No duplicates values are present.

# %% [markdown]
# # Checking unique values

# %%
data.nunique()
# Out:
# Restaurant ID           9551
# Restaurant Name         7446
# Country Code              15
# City                     141
# Address                 8918
# Locality                1208
# Locality Verbose        1265
# Longitude               8120
# Latitude                8677
# Cuisines                1825
# Average Cost for two     140
# Currency                  12
# Has Table booking          2
# Has Online delivery        2
# Is delivering now          2
# Switch to order menu       1
# Price range                4
# Aggregate rating          33
# Rating color               6
# Rating text                6
# Votes                   1012
# Country                   15
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
# To get the information about the dataset

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
#  15  Switch to order menu  9551 non-null   object
#  16  Price range           9551 non-null   int64
#  17  Aggregate rating      9551 non-null   float64
#  18  Rating color          9551 non-null   object
#  19  Rating text           9551 non-null   object
#  20  Votes                 9551 non-null   int64
#  21  Country               9551 non-null   object
# dtypes: float64(3), int64(5), object(14)
# memory usage: 1.7+ MB

# %% [markdown]
# # Here we get the Information regarding Column,Non-Null Count(columns having NaN Values) ,Dtypes and Memory usage of the dataset .... Here we can see that all the columns counts are equal except Cuisines which means that there is no Missing values except in one columns ..

# %% [markdown]
# # NOW LETS CHECK THE NULL VALUES

# %%
data.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %% [markdown]
# Only Cuisines have missing Values

# %%
# visualising null values in dataset
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# No null values present in dataset.

# %%
# Let's visualize NaN values
sns.heatmap(data.isnull(),cmap="ocean")
plt.show()

# %% [markdown]
# It soo less that we are not able to see it in heatmap so lets try other method

# %% [markdown]
# # Univariate Analysis

# %%
sns.countplot(x='Country Code',data=data)
plt.show()

# %% [markdown]
# Whose are having 1 as country code they are having more count.

# %%
sns.countplot(x='Price range',data=data)
plt.show()

# %% [markdown]
# - We can see, Price range of 1 has maximum price range followed by 2.
# - All Price range are decreasing in order.

# %%
sns.countplot(y='Currency',data=data)
plt.show()

# %% [markdown]
# - We can see, Indian Rupees is most used currecny. It means that zomato has main business in India followed by Dollar.
# - Remaining all has no such used, it means zomato not functioning in that country as zomato does in India.

# %%
sns.countplot(x='Has Table booking',data=data)
plt.show()

# %% [markdown]
# - We can see, Zomato has not provivded the table booking. But in some place it provided table booking. May be their zomaato own its Restaurant.

# %%
sns.countplot(x='Has Online delivery',data=data)
plt.show()

# %% [markdown]
# - Most of places has no online delivery available.
# - But in few places has availabled online delivery.

# %%
## Which countries do have online deliveries option
a=data[data['Has Online delivery']=='Yes'].Country.value_counts()

# %%
a.plot.pie(autopct = '%1.1f%%')
plt.title('Country has online delivery')
plt.show()

# %% [markdown]
# - we can see, India has 98.9% online delivery available but UAE has only 1.1% online delivery.
# - But rest of all countries haven't online deliovery.

# %%
sns.countplot(x='Is delivering now',data=data)
plt.show()

# %% [markdown]
# - Most of the places has not availavel delivery Now system.

# %%
plt.figure(figsize=(15,7))
sns.countplot(x='Aggregate rating',data=data)
plt.show()

# %% [markdown]
# - Most of the coustomer has gives 0 aggregate rating than others.
# - 3.1 and 3.2 is most given rating after a 0 aggregate rating.

# %%
sns.countplot(x='Rating color',data=data,)
plt.show()

# %% [markdown]
# - We can see, orange is most used color for rating followed by white.
# - Red color are less used for rating. It means no one dislike the food delivered by zomato.

# %%
sns.countplot(x='Rating text',data=data,)
plt.show()

# %% [markdown]
# - In rating text, Average is the most used test followed by good.
# - But some of customer are not rated the zomato service.
# - Very few customers gives poor rating.

# %%
plt.figure(figsize=(20,5))
sns.countplot(x='Country',data=data)
plt.show()

# %% [markdown]
# - As we observed before that Indian currency is most used. It because of in India is the most of Zomato businees do followed by USA.
# - Rest of all counteries zomato not gives service as in India they gives.

# %%
city_values = data.City.value_counts().values
city_labels = data.City.value_counts().index

# %%
plt.pie(city_values[:5],labels=city_labels[:5],autopct='%1.2f%%')
plt.show()

# %% [markdown]
# 68.7% zomato works in New Delhi foolowed by Gurgaon.
# In this we can observed here these cities are comes in Delhi NCR Region. It means that zomato mostly works in Delhi NCR region.

# %%
# Find top 10 Cuisine
cuisin_val=data.Cuisines.value_counts().values
cuisin_label = data.Cuisines.value_counts().index

# %%
plt.pie(cuisin_val[:10],labels=cuisin_label[:10],autopct='%1.2f%%')
plt.show()

# %% [markdown]
# - We can see, 26.58% people or customers like to eat north Indian cuisine followed by Chinese.
# - These are the top 10 Cuisine like by customes.

# %%
# Find top 10 location
val=data.Locality.value_counts().values
label = data.Locality.value_counts().index

# %%
plt.pie(val[:10],labels=label[:10],autopct='%1.2f%%')
plt.show()

# %% [markdown]
# - These are the top 10 place where most of zomato allines restaurant are located.
# - In which Connaught Place is top among the others it has 13.74% restaurant in it place followed by Rajouri Graden.

# %%
sns.distplot(data['Average Cost for two'])
plt.show()

# %% [markdown]
# - We can see 50% restaurand are affortable.

# %% [markdown]
# # Bivariate Analysis

# %%
plt.figure(figsize=(15,6))
df_good = data.sort_values(by="Average Cost for two",ascending=False)
sns.barplot(x="Country",y="Average Cost for two",data=df_good)
plt.show()

# %% [markdown]
# - We can see, Indonesia has high Average cost for two. It means that Indonesia has high cost of foos than others.
# - Rest of all having low avwerage cost for two.

# %%
plt.figure(figsize=(20,6))
df_good = data.sort_values(by="Average Cost for two",ascending=False).iloc[0:10]
sns.barplot(x="Restaurant Name",y="Average Cost for two",data=df_good)
plt.show()

# %% [markdown]
# - These are the top 10 restaurant name where average cost for two is low than others.
# - In which Satoo hotel has high average cost for two followed by Skye.

# %%
df_good = data.sort_values(by="Average Cost for two",ascending=False).iloc[0:10]
sns.barplot(y="City",x="Average Cost for two",data=df_good)
plt.show()

# %% [markdown]
# These are top cities where has high average cost for two in which Jakartha is in to followed bt Tangerang.

# %%
sns.boxplot(x='Has Online delivery',y='Votes',data=data)
plt.title('Has Online delivery VS Votes')
plt.show()

# %% [markdown]
# - Yes,you can observe that median number of votes for both categories vary.
# - Restaurants accepting online orders tend to get more votes from customers as there is a rating option poping up after each order through zomato application.

# %%
data.groupby('Restaurant Name')['Aggregate rating'].mean().nlargest(10).plot.bar()
plt.show()

# %% [markdown]
# - These are the top 10 restaurant name where most of the coustomers gives good aggregate rating.
# - In which Atlanta is top among the others.

# %%
sns.boxplot(x='Has Online delivery',y='Average Cost for two',data=data)
plt.title('Has Online delivery VS Average Cost for two')
plt.show()

# %% [markdown]
# - Average cost for two has not affected by online delivery system.

# %%
data.groupby('Restaurant Name')['Votes'].mean().nlargest(10).plot.bar()
plt.show()

# %% [markdown]
# - We can see, top 10 reaturant on basis of the customers votes.
# - Toit is top restaurant top among the others whose have top votes followed by Hauz Khans.

# %%
sns.scatterplot(x='Average Cost for two',y='Longitude',data=data)
plt.show()

# %% [markdown]
# - It does not have any linear correlation of both features.
# - Most of the restaurant are above the 50 Longitute.

# %%
sns.scatterplot(x='Average Cost for two',y='Latitude',data=data)
plt.show()

# %% [markdown]
# - We can see, both feature is not have nay linear relationship with each others.

# %%
rating=data.groupby(['Aggregate rating','Rating color','Rating text']).size().reset_index().rename(columns={0:'Rating count'})

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Aggregate rating',y='Rating count',data=rating)
plt.show()

# %% [markdown]
# - When rating is between 4.5 to 4.9-----> Excellent
# - When rating is between 4.0 to 3.4-----> Very good
# - When rating is between 3.5 to 3.9-----> Good
# - When rating is between 2.5 to 2.9-----> Average
# - When rating is between 2.0 to 2.4-----> Poor
# - And 0 rating given by many people

# %%
plt.figure(figsize=(10,6))
df_good = data.sort_values(by="Latitude",ascending=False).iloc[0:10,:]
sns.barplot(y="Restaurant Name",x="Latitude",data=df_good)
plt.show()

# %% [markdown]
# - We can see, by latitude The Kitchen has highest latitude. It mean at high latitude criteria, it is top.
# - We can see, all top 10 restaurant name, where they are generaly lies in nearly same latitude.

# %%
sns.barplot(x='Price range',y='Average Cost for two',data=data)
plt.show()

# %% [markdown]
# - Many restaurant are having as price range 3 it means that those are also having high average price range.
# - It may have directly proportional to each others.

# %%
sns.barplot(x='Rating text',y='Average Cost for two',data=data)
plt.show()

# %% [markdown]
# - Whose having as rating text Excellent those restaurant are having high average cost for two.
# - According to rating test average coat for to is depend.

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Aggregate rating',y='Rating text',data=rating)
plt.show()

# %% [markdown]
# - We can see, Many restaurant are having Excellent as rating text and their Aggrege=ate rating also high it mean more than 4.5.
# - Similarly, Rating text is depending upon the aggregate rating. Whose are having good rating thier rating text also good.

# %%
# Find the countrries name that has given 0 rating
data[data['Rating color']=='White'].groupby(['Aggregate rating','Country']).size().reset_index()
# Out:
#    Aggregate rating         Country     0
# 0               0.0          Brazil     5
# 1               0.0           India  2139
# 2               0.0  United Kingdom     1
# 3               0.0   United States     3

# %% [markdown]
# - We can see, most of the Indian customers are gives the 0 rating.
# - It means that may be service is bad or customers are not intresting in gives any rating.

# %%
Delhi = data[(data.City == 'New Delhi')]
top_locality = Delhi.Locality.value_counts().head(10)
plt.figure(figsize=(12,6))
sns.countplot(y= "Locality", hue="Has Online delivery", data=Delhi[Delhi.Locality.isin(top_locality.index)])
plt.title('Resturants Online Delivery')
plt.show()

# %% [markdown]
# - We can see, most of the place has no online delivery option. or online order system.
# - But Malviya Nagar is top among the restaurant whose having online ordered or online delivery.

# %%
sns.countplot(x='Has Online delivery',hue='Has Table booking',data=data)
plt.show()

# %% [markdown]
# - We can see, those are not providing online delivery they also have less table booking but it doe not have any impact on business because most of the restaurant has not provided online delivery.

# %%
sns.countplot(x='Rating color',hue='Price range',data=data)
plt.show()

# %% [markdown]
# - We can see, As per price range the rating color has change. In Which the Orange rating color has more count than others.

# %%
sns.scatterplot(x='Votes',y='Average Cost for two',data=data)
plt.show()

# %% [markdown]
# - Votes has no linear relationship with Average cost for two.
# - But upto 2000 Votes Average cost has some linear relationship with votes.

# %%
sns.scatterplot(x='Votes',y='Aggregate rating',data=data)
plt.show()

# %% [markdown]
# - There is no direct linear relationship with each others.
# - But After 2 rating there is little linear relationship.

# %% [markdown]
# # Multivariate Analysis

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(x='Aggregate rating',y='Average Cost for two',hue='Has Online delivery',data=data)
plt.show()

# %% [markdown]
# - We can see, very few restaurant has accepted the online delivery it mean online oders.
# - here those restaurant not accepted online odered they also have good rating.

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Aggregate rating',y='Rating count',hue='Rating color',data=rating, palette=['blue','red','orange','yellow','green','darkgreen'])
plt.show()

# %% [markdown]
# - Not Rated count is very high.
# - Maximum number of rating are between 2.5 to 3.4.

# %%
plt.figure(figsize=(15,5))
sns.boxplot(x="Country", y="Average Cost for two", hue="Has Online delivery",data=data)
plt.show()

# %% [markdown]
# - we can see, Indonesia has high average cost for two and they also not available of online delivery. I means they are not having online oder system.
# - rest of all are having low average cost foe two and they may not have any online system or may have online delivery.

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x="Average Cost for two", y="Aggregate rating", hue='Price range', data=Delhi)

plt.xlabel("Average Cost for two")
plt.ylabel("Aggregate rating")
plt.title('Rating vs Cost of Two')
plt.show()

# %% [markdown]
# - I observe there is no linear relation between price and rating. For instance, Restaurants with good rating (like 4–5) have restaurants with all the price range and spread across the entire X axis

# %%
sns.scatterplot(x='Votes',y='Aggregate rating',data=data,hue='Has Online delivery')
plt.show()

# %% [markdown]
# - We can see, many restaurant are having more than 4 rating and they also have online delivery.
# - But many restaurant are dont have online delivery and they have good rating.

# %% [markdown]
# # Encoding of DataFrame

# %%
data.drop(columns=['Restaurant ID','Locality Verbose'],axis=1,inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
for col in data[data.columns[data.dtypes == 'object']]:
    data[col] = le.fit_transform(data[col])

# %%
data.head()
# Out:
#    Restaurant Name  Country Code  City  Address  Locality   Longitude  \
# 0             3749           162    73     8685       171  121.027535
# 1             3173           162    73     6055       593  121.014101
# 2             2897           162    75     4684       308  121.056831
# 3             4707           162    75     8690       862  121.056475
# 4             5523           162    75     8689       862  121.057508
#
#     Latitude  Cuisines  Average Cost for two  Currency  Has Table booking  \
# 0  14.565443       920                  1100         0                  1
# 1  14.553708      1111                  1200         0                  1
# 2  14.581404      1671                  4000         0                  1
# 3  14.585318      1126                  1500         0                  0
# 4  14.584450      1122                  1500         0                  1
#
#    Has Online delivery  Is delivering now  Switch to order menu  Price range  \
# 0                    0                  0                     0            3
# 1                    0                  0                     0            3
# 2                    0                  0                     0            4
# 3                    0                  0                     0            4
# 4                    0                  0                     0            4
#
#    Aggregate rating  Rating color  Rating text  Votes  Country
# 0               4.8             0            1    314        6
# 1               4.5             0            1    591        6
# 2               4.4             1            5    270        6
# 3               4.9             0            1    365        6
# 4               4.8             0            1    229        6

# %% [markdown]
# # Describe the Dataset

# %%
data.describe()
# Out:
#        Restaurant Name  Country Code         City      Address     Locality  \
# count      9551.000000   9551.000000  9551.000000  9551.000000  9551.000000
# mean       3653.204586     18.365616    78.301434  4542.439430   658.128678
# std        2142.917876     56.750546    23.198915  2565.717005   315.866877
# min           0.000000      1.000000     0.000000     0.000000     0.000000
# 25%        1777.500000      1.000000    76.000000  2323.500000   381.000000
# 50%        3595.000000      1.000000    88.000000  4610.000000   696.000000
# 75%        5485.500000      1.000000    88.000000  6746.500000   921.000000
# max        7445.000000    216.000000   140.000000  8917.000000  1207.000000
#
#          Longitude     Latitude    Cuisines  Average Cost for two  \
# count  9551.000000  9551.000000  9551.00000           9551.000000
# mean     64.126574    25.854381   989.95079           1199.210763
# std      41.467058    11.007935   514.72354          16121.183073
# min    -157.948486   -41.330428     0.00000              0.000000
# 25%      77.081343    28.478713   497.00000            250.000000
# 50%      77.191964    28.570469  1127.00000            400.000000
# 75%      77.282006    28.642758  1355.00000            700.000000
# max     174.832089    55.976980  1825.00000         800000.000000
#
#           Currency  Has Table booking  Has Online delivery  Is delivering now  \
# count  9551.000000        9551.000000          9551.000000        9551.000000
# mean      3.977699           0.121244             0.256622           0.003560
# std       0.914242           0.326428             0.436792           0.059561
# min       0.000000           0.000000             0.000000           0.000000
# 25%       4.000000           0.000000             0.000000           0.000000
# 50%       4.000000           0.000000             0.000000           0.000000
# 75%       4.000000           0.000000             1.000000           0.000000
# max      11.000000           1.000000             1.000000           1.000000
#
#        Switch to order menu  Price range  Aggregate rating  Rating color  \
# count                9551.0  9551.000000       9551.000000   9551.000000
# mean                    0.0     1.804837          2.666370      2.952885
# std                     0.0     0.905609          1.516378      1.493048
# min                     0.0     1.000000          0.000000      0.000000
# 25%                     0.0     1.000000          2.500000      2.000000
# 50%                     0.0     2.000000          3.200000      2.000000
# 75%                     0.0     2.000000          3.700000      4.000000
# max                     0.0     4.000000          4.900000      5.000000
#
#        Rating text         Votes      Country
# count  9551.000000   9551.000000  9551.000000
# mean      1.788713    156.909748     3.736781
# std       1.694637    430.169145     2.651963
# min       0.000000      0.000000     0.000000
# 25%       0.000000      5.000000     3.000000
# 50%       2.000000     31.000000     3.000000
# 75%       3.000000    131.000000     3.000000
# max       5.000000  10934.000000    14.000000

# %% [markdown]
# # Outcome of describe of datasets:

# %% [markdown]
# - Difference between 75% and max in Average Cost for two, Evaporation and Votes is high, columns is considerable indicating presence of outliers.
# - In some features Mean to Standrad of deviation difference is close.
# - In Average cost for two has mean and std difference is more.

# %% [markdown]
# # Correlation of the features with target column

# %%
data.corr()
# Out:
#                       Restaurant Name  Country Code      City   Address  \
# Restaurant Name              1.000000      0.020013 -0.001400  0.000764
# Country Code                 0.020013      1.000000 -0.181728 -0.220342
# City                        -0.001400     -0.181728  1.000000 -0.019763
# Address                      0.000764     -0.220342 -0.019763  1.000000
# Locality                     0.004322     -0.120076  0.096443  0.159556
# Longitude                   -0.001920     -0.698299  0.117391  0.185801
# Latitude                     0.009922      0.019792 -0.004301 -0.038654
# Cuisines                     0.051496     -0.129451  0.025764  0.022833
# Average Cost for two         0.019241      0.043225 -0.028838  0.022749
# Currency                     0.009669     -0.033466 -0.071996  0.069499
# Has Table booking            0.041174     -0.061682 -0.003762  0.006428
# Has Online delivery          0.028081     -0.154605  0.012723  0.029874
# Is delivering now            0.011984     -0.018291 -0.014039  0.031267
# Switch to order menu              NaN           NaN       NaN       NaN
# Price range                  0.061275      0.243327 -0.105759 -0.034952
# Aggregate rating             0.029367      0.282189 -0.132163 -0.151153
# Rating color                -0.007312     -0.187174  0.110887  0.071264
# Rating text                  0.012132      0.222685 -0.098985 -0.008029
# Votes                        0.018512      0.154530 -0.078406 -0.101754
# Country                      0.017561      0.968700 -0.180959 -0.235815
#
#                       Locality  Longitude  Latitude  Cuisines  \
# Restaurant Name       0.004322  -0.001920  0.009922  0.051496
# Country Code         -0.120076  -0.698299  0.019792 -0.129451
# City                  0.096443   0.117391 -0.004301  0.025764
# Address               0.159556   0.185801 -0.038654  0.022833
# Locality              1.000000   0.086446 -0.020428  0.006500
# Longitude             0.086446   1.000000  0.043207  0.122457
# Latitude             -0.020428   0.043207  1.000000  0.038646
# Cuisines              0.006500   0.122457  0.038646  1.000000
# Average Cost for two -0.012136   0.045891 -0.111088  0.005755
# Currency              0.023718   0.337334 -0.101864  0.066783
# Has Table booking    -0.065594   0.100488  0.054658  0.050232
# Has Online delivery  -0.030993   0.178757  0.118722 -0.017180
# Is delivering now    -0.007299   0.018787  0.015001  0.007708
# Switch to order menu       NaN        NaN       NaN       NaN
# Price range          -0.114457  -0.078939 -0.166688 -0.005489
# Aggregate rating     -0.174336  -0.116818  0.000516 -0.079494
# Rating color          0.036832   0.059979  0.042590 -0.016180
# Rating text          -0.036969  -0.181466 -0.129447 -0.080025
# Votes                -0.123569  -0.085101 -0.022962 -0.032362
# Country              -0.118786  -0.766221  0.181299 -0.124141
#
#                       Average Cost for two  Currency  Has Table booking  \
# Restaurant Name                   0.019241  0.009669           0.041174
# Country Code                      0.043225 -0.033466          -0.061682
# City                             -0.028838 -0.071996          -0.003762
# Address                           0.022749  0.069499           0.006428
# Locality                         -0.012136  0.023718          -0.065594
# Longitude                         0.045891  0.337334           0.100488
# Latitude                         -0.111088 -0.101864           0.054658
# Cuisines                          0.005755  0.066783           0.050232
# Average Cost for two              1.000000  0.045615           0.007758
# Currency                          0.045615  1.000000           0.000640
# Has Table booking                 0.007758  0.000640           1.000000
# Has Online delivery              -0.018974  0.006991           0.101224
# Is delivering now                -0.001862  0.001458          -0.016816
# Switch to order menu                   NaN       NaN                NaN
# Price range                       0.075083  0.075179           0.501925
# Aggregate rating                  0.051792 -0.006939           0.189998
# Rating color                     -0.049970 -0.040430          -0.021365
# Rating text                       0.031439  0.014598           0.044043
# Votes                             0.067783 -0.027111           0.169422
# Country                          -0.004034 -0.105296          -0.062076
#
#                       Has Online delivery  Is delivering now  \
# Restaurant Name                  0.028081           0.011984
# Country Code                    -0.154605          -0.018291
# City                             0.012723          -0.014039
# Address                          0.029874           0.031267
# Locality                        -0.030993          -0.007299
# Longitude                        0.178757           0.018787
# Latitude                         0.118722           0.015001
# Cuisines                        -0.017180           0.007708
# Average Cost for two            -0.018974          -0.001862
# Currency                         0.006991           0.001458
# Has Table booking                0.101224          -0.016816
# Has Online delivery              1.000000           0.101730
# Is delivering now                0.101730           1.000000
# Switch to order menu                  NaN                NaN
# Price range                      0.077918           0.010940
# Aggregate rating                 0.225699           0.019180
# Rating color                     0.011477           0.001886
# Rating text                     -0.080937          -0.031970
# Votes                            0.074303          -0.001124
# Country                         -0.140464          -0.016607
#
#                       Switch to order menu  Price range  Aggregate rating  \
# Restaurant Name                        NaN     0.061275          0.029367
# Country Code                           NaN     0.243327          0.282189
# City                                   NaN    -0.105759         -0.132163
# Address                                NaN    -0.034952         -0.151153
# Locality                               NaN    -0.114457         -0.174336
# Longitude                              NaN    -0.078939         -0.116818
# Latitude                               NaN    -0.166688          0.000516
# Cuisines                               NaN    -0.005489         -0.079494
# Average Cost for two                   NaN     0.075083          0.051792
# Currency                               NaN     0.075179         -0.006939
# Has Table booking                      NaN     0.501925          0.189998
# Has Online delivery                    NaN     0.077918          0.225699
# Is delivering now                      NaN     0.010940          0.019180
# Switch to order menu                   NaN          NaN               NaN
# Price range                            NaN     1.000000          0.437944
# Aggregate rating                       NaN     0.437944          1.000000
# Rating color                           NaN    -0.140468         -0.367054
# Rating text                            NaN     0.164242         -0.182662
# Votes                                  NaN     0.309444          0.313691
# Country                                NaN     0.178035          0.255591
#
#                       Rating color  Rating text     Votes   Country
# Restaurant Name          -0.007312     0.012132  0.018512  0.017561
# Country Code             -0.187174     0.222685  0.154530  0.968700
# City                      0.110887    -0.098985 -0.078406 -0.180959
# Address                   0.071264    -0.008029 -0.101754 -0.235815
# Locality                  0.036832    -0.036969 -0.123569 -0.118786
# Longitude                 0.059979    -0.181466 -0.085101 -0.766221
# Latitude                  0.042590    -0.129447 -0.022962  0.181299
# Cuisines                 -0.016180    -0.080025 -0.032362 -0.124141
# Average Cost for two     -0.049970     0.031439  0.067783 -0.004034
# Currency                 -0.040430     0.014598 -0.027111 -0.105296
# Has Table booking        -0.021365     0.044043  0.169422 -0.062076
# Has Online delivery       0.011477    -0.080937  0.074303 -0.140464
# Is delivering now         0.001886    -0.031970 -0.001124 -0.016607
# Switch to order menu           NaN          NaN       NaN       NaN
# Price range              -0.140468     0.164242  0.309444  0.178035
# Aggregate rating         -0.367054    -0.182662  0.313691  0.255591
# Rating color              1.000000     0.163717 -0.169044 -0.155486
# Rating text               0.163717     1.000000  0.203969  0.203846
# Votes                    -0.169044     0.203969  1.000000  0.155161
# Country                  -0.155486     0.203846  0.155161  1.000000

# %%
data.corr()['Average Cost for two'].sort_values()
# Out:
# Latitude               -0.111088
# Rating color           -0.049970
# City                   -0.028838
# Has Online delivery    -0.018974
# Locality               -0.012136
# Country                -0.004034
# Is delivering now      -0.001862
# Cuisines                0.005755
# Has Table booking       0.007758
# Restaurant Name         0.019241
# Address                 0.022749
# Rating text             0.031439
# Country Code            0.043225
# Currency                0.045615
# Longitude               0.045891
# Aggregate rating        0.051792
# Votes                   0.067783
# Price range             0.075083
# Average Cost for two    1.000000
# Switch to order menu         NaN
# Name: Average Cost for two, dtype: float64

# %%
plt.figure(figsize=(15,10))
sns.heatmap(data.corr(), annot=True, fmt ='.2f')
plt.show()

# %% [markdown]
# # Outcome of Correlation

# %% [markdown]
# - Price range has 8% positive correlation with target column.
# - Votes has 7% positive correlation with target column.

# %% [markdown]
# # Features correlation to each other

# %% [markdown]
# - Country code has 97% positive correlation with country.
# - Longitude has 77% negative correlation with country.
# - Has Table Booking has 50% positive correlation with Price range.
# - Price range has 44% positive correlation with Aggregate rating.
# - Country code has 77% positive correlation with Longitude.

# %% [markdown]
# # Visualizing correlation of feature columns with label column

# %%
plt.figure(figsize = (20,8))
data.corr()['Average Cost for two'].sort_values(ascending = False).drop(['Average Cost for two']).plot(kind='bar',color = 'c')
plt.xlabel('Features',fontsize=15)
plt.ylabel('Average Cost for two',fontsize=15)
plt.title('correlation',fontsize = 18)
plt.show()

# %% [markdown]
# - It is observed that Price range, Votes and Aggregate rating have the highest positive correlation with Average cost for two.
# - Switch to oder menu, Longitude and rating color have the highest negative correlation with Average cost for two.

# %% [markdown]
# # Checking Distribution of data

# %%
data.shape
# Out:
# (9551, 20)

# %%
plt.figure(figsize=(25,30))
plotnumber = 1

for column in data:
    if plotnumber <=20:
        ax = plt.subplot(5,4,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column, fontsize=20)
    plotnumber +=1
plt.show()

# %% [markdown]
# - All features are having some skewness.
# - Average cost for two and votes are seem to be present a outliers.

# %% [markdown]
# # Lets check skewness

# %%
data.skew()
# Out:
# Restaurant Name          0.044637
# Country Code             3.043965
# City                    -1.193777
# Address                 -0.040407
# Locality                -0.253550
# Longitude               -2.807328
# Latitude                -3.081635
# Cuisines                -0.305484
# Average Cost for two    35.477915
# Currency                 2.858093
# Has Table booking        2.321100
# Has Online delivery      1.114620
# Is delivering now       16.673412
# Switch to order menu     0.000000
# Price range              0.889618
# Aggregate rating        -0.954130
# Rating color             0.046009
# Rating text              0.431408
# Votes                    8.807637
# Country                  3.312721
# dtype: float64

# %% [markdown]
# Outcome of the skewness:
#
# - Skewness threshold is taken is +/-0.65.
# - Almost all features are having some skewness.

# %% [markdown]
# # Checking Outliers

# %%
plt.figure(figsize=(25,30))
plotnumber = 1

for column in data:
    if plotnumber <=20:
        plt.subplot(5,4,plotnumber)
        ax = sns.boxplot(data=data[column])
        plt.xlabel(column, fontsize=20)
    plotnumber +=1
plt.show()

# %% [markdown]
# - Restaurant Name, Address, Rating color, Rating text, Has online delivery, Cuisine and Locality are not having Outliers.
# - Some feature are having outliers but those are categorical features.

# %% [markdown]
# # Removing Outliers

# %%
data.head(1)
# Out:
#    Restaurant Name  Country Code  City  Address  Locality   Longitude  \
# 0             3749           162    73     8685       171  121.027535
#
#     Latitude  Cuisines  Average Cost for two  Currency  Has Table booking  \
# 0  14.565443       920                  1100         0                  1
#
#    Has Online delivery  Is delivering now  Switch to order menu  Price range  \
# 0                    0                  0                     0            3
#
#    Aggregate rating  Rating color  Rating text  Votes  Country
# 0               4.8             0            1    314        6

# %%
from scipy.stats import zscore

z_score = zscore(data[['Average Cost for two','Votes']]) # Only removing outliers from continuous data
abs_z_score = np.abs(z_score)    # Apply the formula and get the scaled data

filtering_entry = (abs_z_score  < 3).all(axis=1)

df = data[filtering_entry]

# %%
df.shape
# Out:
# (9362, 20)

# %%
data.shape
# Out:
# (9551, 20)

# %% [markdown]
# # Percentage of data loss

# %%
data_loss = ((9551 - 9362)/9551*100)
print(data_loss,'%')
# Out:
# 1.978850382158936 %

# %% [markdown]
# # Checking Multicollinearity

# %%
x = df.drop(columns=['Average Cost for two'],axis=1)
y = df['Average Cost for two']

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler= StandardScaler()
scaled_X = scaler.fit_transform(x)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = pd.DataFrame()

# %%
vif["Features"] = x.columns
vif['vif'] = [variance_inflation_factor(scaled_X,i) for i in range(scaled_X.shape[1])]
vif
# Out:
#                 Features        vif
# 0        Restaurant Name   1.008700
# 1           Country Code  48.278765
# 2                   City   1.081830
# 3                Address   1.106130
# 4               Locality   1.068077
# 5              Longitude   5.031287
# 6               Latitude   3.037873
# 7               Cuisines   1.043922
# 8               Currency   1.294013
# 9      Has Table booking   1.482431
# 10   Has Online delivery   1.168622
# 11     Is delivering now   1.014266
# 12  Switch to order menu        NaN
# 13           Price range   1.949610
# 14      Aggregate rating   1.947962
# 15          Rating color   1.221294
# 16           Rating text   1.426143
# 17                 Votes   1.613811
# 18               Country  66.489649

# %% [markdown]
# - If VIF > 10, It means multicollinearity is present.
# - MultiCollinearity exists in Country Code, Switch to order menu and Country Based on ANOVA F scores.

# %% [markdown]
# # Droping columns whose having multicollinearity

# %%
df.drop(columns=['Country Code','Switch to order menu','Country'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (9362, 17)

# %%
x = df.drop(columns=['Average Cost for two'],axis=1)
y = df['Average Cost for two']

# %% [markdown]
# # Selecting Kbest Features

# %%
from sklearn.feature_selection import SelectKBest, f_classif

# %%
bestfeat = SelectKBest(score_func = f_classif, k = 'all')
fit = bestfeat.fit(x,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(x.columns)

# %%
fit = bestfeat.fit(x,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(x.columns)
dfcolumns.head()
featureScores = pd.concat([dfcolumns,dfscores],axis = 1)
featureScores.columns = ['Feature', 'Score']
print(featureScores.nlargest(35,'Score'))
# Out:
#                 Feature       Score
# 11          Price range  418.202989
# 4             Longitude  142.353602
# 8     Has Table booking   80.635590
# 7              Currency   29.041295
# 15                Votes   25.818126
# 12     Aggregate rating   22.275744
# 5              Latitude   15.805349
# 9   Has Online delivery   11.752010
# 2               Address    7.795143
# 14          Rating text    7.144425
# 1                  City    4.863372
# 13         Rating color    4.044857
# 6              Cuisines    3.786064
# 3              Locality    3.379433
# 10    Is delivering now    2.063234
# 0       Restaurant Name    1.358213

# %% [markdown]
# # Selecting best features based on their scores

# %%
x_best = x.drop(columns=['Restaurant Name','Is delivering now']).copy()

# %% [markdown]
# # Data Skewness Before removing

# %%
data.skew()
# Out:
# Restaurant Name          0.044637
# Country Code             3.043965
# City                    -1.193777
# Address                 -0.040407
# Locality                -0.253550
# Longitude               -2.807328
# Latitude                -3.081635
# Cuisines                -0.305484
# Average Cost for two    35.477915
# Currency                 2.858093
# Has Table booking        2.321100
# Has Online delivery      1.114620
# Is delivering now       16.673412
# Switch to order menu     0.000000
# Price range              0.889618
# Aggregate rating        -0.954130
# Rating color             0.046009
# Rating text              0.431408
# Votes                    8.807637
# Country                  3.312721
# dtype: float64

# %% [markdown]
# # Data Skeweness After Removing Skewness

# %%
from sklearn.preprocessing import power_transform
x = power_transform(x_best,method='yeo-johnson')

# %%
trans = pd.DataFrame(x)

# %%
trans.skew()
# Out:
# 0    -0.198500
# 1    -0.302620
# 2    -0.306522
# 3    -0.795230
# 4    -0.259015
# 5    -0.382346
# 6     0.447069
# 7     2.382516
# 8     1.120081
# 9     0.197391
# 10   -0.615772
# 11   -0.100142
# 12   -0.055331
# 13   -0.021285
# dtype: float64

# %%
x = scaler.fit_transform(x)

# %%
x
# Out:
# array([[-0.40644576,  1.47370479, -1.5689573 , ..., -2.26885617,
#         -0.20420612,  1.30223393],
#        [-0.40644576,  0.61835876, -0.20264132, ..., -2.26885617,
#         -0.20420612,  1.65627302],
#        [-0.310708  ,  0.13463254, -1.11660537, ..., -1.38742706,
#          1.51689551,  1.21890769],
#        ...,
#        [ 3.88657629,  0.58789144, -0.32621236, ...,  1.32393817,
#          0.39794913,  1.71976831],
#        [ 3.88657629,  0.58823442, -0.32621236, ..., -1.38742706,
#          1.51689551,  1.8967675 ],
#        [ 3.88657629, -0.0228778 ,  0.04024681, ..., -1.38742706,
#          1.51689551,  1.65627302]])

# %% [markdown]
# # Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %% [markdown]
# # Linear Regression

# %% [markdown]
# # Finding Best Random State

# %%
# finding Best Random state
maxAccu=0
maxRS=0

for i in range(1, 200):
    X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=i)
    lr=LinearRegression()
    lr.fit(X_train, y_train)
    pred = lr.predict(X_test)
    r2 = r2_score(y_test, pred)
    
    if r2>maxAccu:
        maxAccu=r2
        maxRS=i

print("Best r2 score is", maxAccu,"on Random State", maxRS)
# Out:
# Best r2 score is 0.5808124244702715 on Random State 118

# %%
# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(x, y, train_size=0.7, test_size=0.3, random_state=118)

# %%
regressors = {
    'Linear Regression' : LinearRegression(),
    
}

results=pd.DataFrame(columns=['MAE','MSE', 'RMSE', 'R2-score'])

for method,func in regressors.items():
    model = func.fit(X_train,y_train)
    pred = model.predict(X_test)
    results.loc[method]= [np.round(mean_absolute_error(y_test,pred),3),
                          np.round(mean_squared_error(y_test,pred),3),
                          np.sqrt(mean_squared_error(y_test,pred)),
                          np.round(r2_score(y_test,pred),3)
                          
                         ]

# %%
results
# Out:
#                        MAE         MSE        RMSE  R2-score
# Linear Regression  211.021  134382.342  366.581972     0.581

# %% [markdown]
# # Cross - Validation of the model

# %%
y_pred = lr.predict(X_test)
from sklearn.model_selection import cross_val_score
lss  = r2_score(y_test,y_pred)

# %%
for j in range(4,10):
    isscore = cross_val_score(lr,x,y,cv=j)
    lsc = isscore.mean()
    print("At cv:-",j)
    print('Cross validation score is:-',lsc*100)
    print('accuracy_score is:-',lss*100)
    print('\n')
# Out:
# At cv:- 4
# Cross validation score is:- 24.207216032358573
# accuracy_score is:- 58.26131963005297
#
#
# At cv:- 5
# Cross validation score is:- 4.250194222186945
# accuracy_score is:- 58.26131963005297
#
#
# At cv:- 6
# Cross validation score is:- 8.493835849476646
# accuracy_score is:- 58.26131963005297
#
#
# At cv:- 7
# Cross validation score is:- 3.146039473674099
# accuracy_score is:- 58.26131963005297
#
#
# At cv:- 8
# Cross validation score is:- -0.3584863458359677
# accuracy_score is:- 58.26131963005297
#
#
# At cv:- 9
# Cross validation score is:- -5.626502785017018
# accuracy_score is:- 58.26131963005297

# %%
lsscore_selected = cross_val_score(lr,x,y,cv=4).mean()
print("The cv score is: ",lsscore_selected,"\nThe accuracy score is: ",lss)
# Out:
# The cv score is:  0.24207216032358572
# The accuracy score is:  0.5826131963005297

# %% [markdown]
# # RandomForest Regressor

# %% [markdown]
# # Finding Best Random State

# %%
# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(x, y, train_size=0.7, test_size=0.3, random_state=94)

# %%
regressors = {
    
    'Random Forest' : RandomForestRegressor(),
    
}

results=pd.DataFrame(columns=['MAE','MSE', 'RMSE', 'R2-score'])

for method,func in regressors.items():
    model = func.fit(X_train,y_train)
    pred = model.predict(X_test)
    results.loc[method]= [np.round(mean_absolute_error(y_test,pred),3),
                          np.round(mean_squared_error(y_test,pred),3),
                          np.sqrt(mean_squared_error(y_test,pred)),
                          np.round(r2_score(y_test,pred),3)
                          
                         ]

# %%
results
# Out:
#                    MAE        MSE        RMSE  R2-score
# Random Forest  104.333  37083.006  192.569482     0.899

# %% [markdown]
# # Cross - Validation of the model

# %%
rf = RandomForestRegressor()
rf.fit(X_train,y_train)
y_pred = rf.predict(X_test)
lss  = r2_score(y_test,y_pred)

# %%
for j in range(4,10):
    isscore = cross_val_score(rf,x,y,cv=j)
    lsc = isscore.mean()
    print("At cv:-",j)
    print('Cross validation score is:-',lsc*100)
    print('accuracy_score is:-',lss*100)
    print('\n')
# Out:
# At cv:- 4
# Cross validation score is:- 60.540732755072234
# accuracy_score is:- 89.94218812179201
#
#
# At cv:- 5
# Cross validation score is:- 43.60967214036325
# accuracy_score is:- 89.94218812179201
#
#
# At cv:- 6
# Cross validation score is:- 49.098989564209155
# accuracy_score is:- 89.94218812179201
#
#
# At cv:- 7
# Cross validation score is:- 44.10399379510398
# accuracy_score is:- 89.94218812179201
#
#
# At cv:- 8
# Cross validation score is:- 41.605455742917194
# accuracy_score is:- 89.94218812179201
#
#
# At cv:- 9
# Cross validation score is:- 40.533834549692116
# accuracy_score is:- 89.94218812179201

# %%
lsscore_selected = cross_val_score(rf,x,y,cv=4).mean()
print("The cv score is: ",lsscore_selected,"\nThe accuracy score is: ",lss)
# Out:
# The cv score is:  0.5985583326721385
# The accuracy score is:  0.8994218812179201

# %% [markdown]
# # Gradient Boosting Regressor

# %% [markdown]
# # Finding Best Random State

# %%
# finding Best Random state
maxAccu=0
maxRS=0

for i in range(1, 200):
    X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=i)
    gbr = GradientBoostingRegressor()
    gbr.fit(X_train, y_train)
    pred = gbr.predict(X_test)
    r2 = r2_score(y_test, pred)
    
    if r2>maxAccu:
        maxAccu=r2
        maxRS=i

print("Best r2 score is", maxAccu,"on Random State", maxRS)
# Out:
# Best r2 score is 0.8835067803523938 on Random State 16

# %%
# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(x, y, train_size=0.7, test_size=0.3, random_state=16)

# %%
regressors = {
    
    'Gradient Boost Regressor' : GradientBoostingRegressor(),
    
}

results=pd.DataFrame(columns=['MAE','MSE', 'RMSE', 'R2-score'])

for method,func in regressors.items():
    model = func.fit(X_train,y_train)
    pred = model.predict(X_test)
    results.loc[method]= [np.round(mean_absolute_error(y_test,pred),3),
                          np.round(mean_squared_error(y_test,pred),3),
                          np.sqrt(mean_squared_error(y_test,pred)),
                          np.round(r2_score(y_test,pred),3)
                          
                         ]

# %%
results
# Out:
#                               MAE        MSE        RMSE  R2-score
# Gradient Boost Regressor  114.704  38788.512  196.947994     0.884

# %% [markdown]
# # Cross-validation of the model

# %%
gbr = GradientBoostingRegressor()
gbr.fit(X_train,y_train)
y_pred = gbr.predict(X_test)
from sklearn.model_selection import cross_val_score
lss  = r2_score(y_test,y_pred)

# %%
for j in range(4,10):
    isscore = cross_val_score(gbr,x,y,cv=j)
    lsc = isscore.mean()
    print("At cv:-",j)
    print('Cross validation score is:-',lsc*100)
    print('accuracy_score is:-',lss*100)
    print('\n')
# Out:
# At cv:- 4
# Cross validation score is:- 69.0686950503508
# accuracy_score is:- 88.39888389361461
#
#
# At cv:- 5
# Cross validation score is:- 58.01428563345434
# accuracy_score is:- 88.39888389361461
#
#
# At cv:- 6
# Cross validation score is:- 57.004994443533974
# accuracy_score is:- 88.39888389361461
#
#
# At cv:- 7
# Cross validation score is:- 55.69124673132564
# accuracy_score is:- 88.39888389361461
#
#
# At cv:- 8
# Cross validation score is:- 55.61053734693955
# accuracy_score is:- 88.39888389361461
#
#
# At cv:- 9
# Cross validation score is:- 52.837133222873845
# accuracy_score is:- 88.39888389361461

# %%
lsscore_selected = cross_val_score(gbr,x,y,cv=4).mean()
print("The cv score is: ",lsscore_selected,"\nThe accuracy score is: ",lss)
# Out:
# The cv score is:  0.6901860149194332
# The accuracy score is:  0.8839888389361461

# %% [markdown]
# # KNeighbors Regressor

# %% [markdown]
# # Finding Best Random State

# %%
# finding Best Random state
maxAccu=0
maxRS=0

for i in range(1, 200):
    X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=i)
    knn = KNeighborsRegressor()
    knn.fit(X_train, y_train)
    pred = knn.predict(X_test)
    r2 = r2_score(y_test, pred)
    
    if r2>maxAccu:
        maxAccu=r2
        maxRS=i

print("Best r2 score is", maxAccu,"on Random State", maxRS)
# Out:
# Best r2 score is 0.7609839116527098 on Random State 118

# %%
# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(x, y, train_size=0.7, test_size=0.3, random_state=118)

# %%
regressors = {
    
    'KNN Regressor': KNeighborsRegressor()
}

results=pd.DataFrame(columns=['MAE','MSE', 'RMSE', 'R2-score'])

for method,func in regressors.items():
    model = func.fit(X_train,y_train)
    pred = model.predict(X_test)
    results.loc[method]= [np.round(mean_absolute_error(y_test,pred),3),
                          np.round(mean_squared_error(y_test,pred),3),
                          np.sqrt(mean_squared_error(y_test,pred)),
                          np.round(r2_score(y_test,pred),3)
                          
                         ]

# %%
results
# Out:
#                    MAE        MSE        RMSE  R2-score
# KNN Regressor  150.406  76623.315  276.809167     0.761

# %% [markdown]
# # Cross-validation of the model

# %%
knn = KNeighborsRegressor()
knn.fit(X_train,y_train)
y_pred = knn.predict(X_test)
lss  = r2_score(y_test,y_pred)

# %%
for j in range(4,10):
    isscore = cross_val_score(knn,x,y,cv=j)
    lsc = isscore.mean()
    print("At cv:-",j)
    print('Cross validation score is:-',lsc*100)
    print('accuracy_score is:-',lss*100)
    print('\n')
# Out:
# At cv:- 4
# Cross validation score is:- 43.65268928937144
# accuracy_score is:- 76.09839116527098
#
#
# At cv:- 5
# Cross validation score is:- 32.48167330585002
# accuracy_score is:- 76.09839116527098
#
#
# At cv:- 6
# Cross validation score is:- 37.19162355927823
# accuracy_score is:- 76.09839116527098
#
#
# At cv:- 7
# Cross validation score is:- 35.05614718189994
# accuracy_score is:- 76.09839116527098
#
#
# At cv:- 8
# Cross validation score is:- 29.169372538717752
# accuracy_score is:- 76.09839116527098
#
#
# At cv:- 9
# Cross validation score is:- 27.879504598254535
# accuracy_score is:- 76.09839116527098

# %%
lsscore_selected = cross_val_score(knn,x,y,cv=4).mean()
print("The cv score is: ",lsscore_selected,"\nThe accuracy score is: ",lss)
# Out:
# The cv score is:  0.4365268928937144
# The accuracy score is:  0.7609839116527098

# %% [markdown]
# # Selecting The Best Model

# %% [markdown]
# # Based on comparing Accuracy Score results with Cross Validation results, it is determined Gradient Boosting Regressor is the best model. It has least difference between accuracy score and cross validation.

# %% [markdown]
# # Hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# %%
# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(x, y, train_size=0.7, test_size=0.3, random_state=891)

# %%
param = {
             'min_samples_split':[2,5,10],
             'min_samples_leaf':[1,3,4],
             'max_depth':[5,10,15],
             'learning_rate': [0.1,0.2,0.3],
              'n_estimators':[150,200,250],
             }

# %%
gbr = GradientBoostingRegressor(learning_rate=0.1, n_estimators=150, min_samples_split=10, min_samples_leaf=1, max_depth=15)

gbr.fit(X_train,y_train)

pred = gbr.predict(X_test)

r2_score(y_test,pred)
# Out:
# 0.884607664076866

# %% [markdown]
# # Plot Actual VS Predicted Averahe Cost for two

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=y_pred)
plt.plot(y_test,y_test)
plt.xlabel('Actual Average Cost for two')
plt.ylabel('Predicted Average Cost for two')
plt.show()

# %% [markdown]
# # Model Save

# %%
import pickle
pickle.dump(gbr, open('Zomato_Final','wb'))

# %% [markdown]
# # Predicting the Average Cost for two

# %%
Prediction_accuracy = pd.DataFrame({'Predictions': gbr.predict(x), 'Actual Values': y})
Prediction_accuracy.head(30)
# Out:
#     Predictions  Actual Values
# 0   1100.261289           1100
# 1   1201.223950           1200
# 2   3999.018837           4000
# 3   1498.605785           1500
# 4   1501.323831           1500
# 5    997.427646           1000
# 6   1999.323889           2000
# 7   2000.764679           2000
# 8   5996.234476           6000
# 9   1101.270449           1100
# 10  1470.742890            800
# 11   900.583473            900
# 12   887.983805            800
# 13  1000.071270           1000
# 14   855.905565            700
# 15   807.180210            800
# 16   834.182662            850
# 17  1195.118257           1200
# 18   597.666557            600
# 19  1502.036676           1500
# 20  2999.421028           3000
# 21  1800.681386           1800
# 22    85.810979             55
# 23     5.186324             30
# 24    45.664065             45
# 25    62.017056             60
# 26    45.859413             50
# 27    79.958065             80
# 28    68.459376             90
# 29   155.008874            200

# %% [markdown]
# # Model Building For Predicting Price range (Classification)

# %%
df.head()
# Out:
#    Restaurant Name  City  Address  Locality   Longitude   Latitude  Cuisines  \
# 0             3749    73     8685       171  121.027535  14.565443       920
# 1             3173    73     6055       593  121.014101  14.553708      1111
# 2             2897    75     4684       308  121.056831  14.581404      1671
# 3             4707    75     8690       862  121.056475  14.585318      1126
# 4             5523    75     8689       862  121.057508  14.584450      1122
#
#    Average Cost for two  Currency  Has Table booking  Has Online delivery  \
# 0                  1100         0                  1                    0
# 1                  1200         0                  1                    0
# 2                  4000         0                  1                    0
# 3                  1500         0                  0                    0
# 4                  1500         0                  1                    0
#
#    Is delivering now  Price range  Aggregate rating  Rating color  \
# 0                  0            3               4.8             0
# 1                  0            3               4.5             0
# 2                  0            4               4.4             1
# 3                  0            4               4.9             0
# 4                  0            4               4.8             0
#
#    Rating text  Votes
# 0            1    314
# 1            1    591
# 2            5    270
# 3            1    365
# 4            1    229

# %% [markdown]
# # Checking Multicollinearity

# %%
x = df.drop(columns=['Price range'],axis=1)
y = df['Price range']

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler= StandardScaler()
scaled_X = scaler.fit_transform(x)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = pd.DataFrame()

# %%
vif["Features"] = x.columns
vif['vif'] = [variance_inflation_factor(scaled_X,i) for i in range(scaled_X.shape[1])]
vif
# Out:
#                 Features       vif
# 0        Restaurant Name  1.007167
# 1                   City  1.073697
# 2                Address  1.098924
# 3               Locality  1.067976
# 4              Longitude  1.436619
# 5               Latitude  1.056336
# 6               Cuisines  1.039253
# 7   Average Cost for two  1.741087
# 8               Currency  1.171581
# 9      Has Table booking  1.596766
# 10   Has Online delivery  1.154632
# 11     Is delivering now  1.014095
# 12      Aggregate rating  1.773284
# 13          Rating color  1.206737
# 14           Rating text  1.360286
# 15                 Votes  1.546770

# %% [markdown]
# - If VIF > 10, It means multicollinearity is present.
# - MultiCollinearity not exists Based on ANOVA F scores.

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
from sklearn.preprocessing import power_transform
x = power_transform(x,method='yeo-johnson')

# %%
from sklearn.preprocessing import StandardScaler

# transform my dataset into standard normal distribution
sc = StandardScaler()
x = sc.fit_transform(x)
x
# Out:
# array([[ 0.15320122, -0.40644576,  1.47370479, ..., -2.26885617,
#         -0.20420612,  1.30223393],
#        [-0.10300615, -0.40644576,  0.61835876, ..., -2.26885617,
#         -0.20420612,  1.65627302],
#        [-0.23099771, -0.310708  ,  0.13463254, ..., -1.38742706,
#          1.51689551,  1.21890769],
#        ...,
#        [-0.15079956,  3.88657629,  0.58789144, ...,  1.32393817,
#          0.39794913,  1.71976831],
#        [-1.61804193,  3.88657629,  0.58823442, ..., -1.38742706,
#          1.51689551,  1.8967675 ],
#        [ 1.50177812,  3.88657629, -0.0228778 , ..., -1.38742706,
#          1.51689551,  1.65627302]])

# %% [markdown]
# # Balancing the Data

# %%
from imblearn.over_sampling import SMOTE as sm

smt_x,smt_y = sm().fit_resample(x,y)

# %%
smt_y.value_counts()
# Out:
# 3    4437
# 4    4437
# 2    4437
# 1    4437
# Name: Price range, dtype: int64

# %% [markdown]
# # LogisticRegression

# %% [markdown]
# # Finding Best Random State

# %%
# finding Best Random state
maxAccu=0
maxRS=0

for i in range(1, 200):
    x_train, x_test, y_train, y_test = train_test_split(smt_x, smt_y, test_size=0.3, random_state=i)
    lr=LogisticRegression()
    lr.fit(x_train, y_train)
    pred = lr.predict(x_test)
    accuracy = accuracy_score(y_test, pred)
    
    if accuracy>maxAccu:
        maxAccu=accuracy
        maxRS=i

print("Best Accuracy score is", maxAccu,"on Random State", maxRS)
# Out:
# Best Accuracy score is 0.6679812206572769 on Random State 125

# %%
x_train, x_test, y_train, y_test = train_test_split(smt_x, smt_y, test_size=0.3, random_state=158)

# %%
lr = LogisticRegression()
lr.fit(x_train,y_train)

y_pred = lr.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.6644131455399062

# %% [markdown]
# # Cross - validation for logistic Regression

# %%
from sklearn.model_selection import cross_val_score

# %%
pred_lr = lr.predict(x_test)
accu = accuracy_score(y_test,pred_lr)

# %%
for j in range(4,10):
    cross = cross_val_score(lr,x,y,cv=j)
    lsc = cross.mean()
    print("At cv:-",j)
    print('Cross validation score is:-',lsc*100)
    print('accuracy_score is:-',accu*100)
    print('\n')
# Out:
# At cv:- 4
# Cross validation score is:- 78.1891733023728
# accuracy_score is:- 66.44131455399062
#
#
# At cv:- 5
# Cross validation score is:- 76.88664489985901
# accuracy_score is:- 66.44131455399062
#
#
# At cv:- 6
# Cross validation score is:- 75.87240674124082
# accuracy_score is:- 66.44131455399062
#
#
# At cv:- 7
# Cross validation score is:- 75.52009041120263
# accuracy_score is:- 66.44131455399062
#
#
# At cv:- 8
# Cross validation score is:- 75.658725466582
# accuracy_score is:- 66.44131455399062
#
#
# At cv:- 9
# Cross validation score is:- 75.32787137614227
# accuracy_score is:- 66.44131455399062

# %%
lsscore_selected = cross_val_score(lr,x,y,cv=4).mean()
print("The cv score is: ",lsscore_selected,"\nThe accuracy score is: ",accu)
# Out:
# The cv score is:  0.7818917330237279
# The accuracy score is:  0.6644131455399062

# %%
def metric_score(clf, x_train_ns,x_test,y_train_ns,y_test, train=True):
    if train:
        
        y_pred = clf.predict(x_train_ns)

        print("\n========================== Train Result=============================")

        print(f"Accuracy Score: {accuracy_score(y_train_ns, y_pred) * 100:.2f}%")

    
    elif train==False:
        pred = clf.predict(x_test)
        
        print("\n==========================Test Result=======================")
        print(f"Accuracy Score: {accuracy_score(y_test,pred) * 100:.2f}%")
        
        print("\n \n Test Classification Report \n", classification_report(y_test, pred, digits=2))
        
        print('\n Confusion Matrix: \n',confusion_matrix(y_test,pred))

# %% [markdown]
# # Random Forest Classifier

# %% [markdown]
# # Finding Best Random State

# %%
x_train, x_test, y_train, y_test = train_test_split(smt_x, smt_y, test_size=0.3, random_state=13)

# %%
rf = RandomForestClassifier()
rf.fit(x_train,y_train)

metric_score(rf,x_train,x_test,y_train, y_test, train=True)

metric_score(rf,x_train,x_test,y_train, y_test, train=False)
# Out:
# ========================== Train Result=============================
# Accuracy Score: 100.00%
#
# ==========================Test Result=======================
# Accuracy Score: 99.08%
#
#
#  Test Classification Report
#                precision    recall  f1-score   support
#
#            1       1.00      0.99      0.99      1303
#            2       0.99      0.99      0.99      1316
#            3       0.98      0.99      0.99      1334
#            4       0.99      0.99      0.99      1372
#
#     accuracy                           0.99      5325
#    macro avg       0.99      0.99      0.99      5325
# weighted avg       0.99      0.99      0.99      5325
#
#
#  Confusion Matrix:
#  [[1294    7    2    0]
#  [   5 1300   11    0]
#  [   1    6 1318    9]
#  [   0    0    8 1364]]

# %% [markdown]
# # Cross - Validation for Random Forest classifier

# %%
pred_rf = rf.predict(x_test)
accu = accuracy_score(y_test,pred_rf)

# %%
for j in range(4,10):
    cross = cross_val_score(rf,x,y,cv=j)
    lsc = cross.mean()
    print("At cv:-",j)
    print('Cross validation score is:-',lsc*100)
    print('accuracy_score is:-',accu*100)
    print('\n')
# Out:
# At cv:- 4
# Cross validation score is:- 88.67879166255929
# accuracy_score is:- 99.07981220657277
#
#
# At cv:- 5
# Cross validation score is:- 84.44045728549199
# accuracy_score is:- 99.07981220657277
#
#
# At cv:- 6
# Cross validation score is:- 90.42047202921643
# accuracy_score is:- 99.07981220657277
#
#
# At cv:- 7
# Cross validation score is:- 89.8974488957417
# accuracy_score is:- 99.07981220657277
#
#
# At cv:- 8
# Cross validation score is:- 89.16219609217048
# accuracy_score is:- 99.07981220657277
#
#
# At cv:- 9
# Cross validation score is:- 89.66428770823582
# accuracy_score is:- 99.07981220657277

# %%
lsscore_selected = cross_val_score(rf,x,y,cv=6).mean()
print("The cv score is: ",lsscore_selected,"\nThe accuracy score is: ",accu)
# Out:
# The cv score is:  0.9044177110881146
# The accuracy score is:  0.9907981220657277

# %% [markdown]
# # Gradient Boosting Classifier

# %% [markdown]
# # Finding Best Random State

# %%
x_train, x_test, y_train, y_test = train_test_split(smt_x, smt_y, test_size=0.3, random_state=145)

# %%
gbc=GradientBoostingClassifier()
gbc.fit(x_train,y_train)

metric_score(gbc,x_train,x_test,y_train, y_test, train=True)

metric_score(gbc,x_train,x_test,y_train, y_test, train=False)
# Out:
# ========================== Train Result=============================
# Accuracy Score: 98.53%
#
# ==========================Test Result=======================
# Accuracy Score: 97.80%
#
#
#  Test Classification Report
#                precision    recall  f1-score   support
#
#            1       0.99      1.00      0.99      1350
#            2       0.99      0.97      0.98      1333
#            3       0.95      0.97      0.96      1287
#            4       0.98      0.97      0.98      1355
#
#     accuracy                           0.98      5325
#    macro avg       0.98      0.98      0.98      5325
# weighted avg       0.98      0.98      0.98      5325
#
#
#  Confusion Matrix:
#  [[1348    1    1    0]
#  [  14 1299   19    1]
#  [   0   16 1251   20]
#  [   0    0   45 1310]]

# %% [markdown]
# # Cross - validation For GradientBoosting Classifier

# %%
pred_gbc = gbc.predict(x_test)
accu = accuracy_score(y_test,pred_gbc)

# %%
for j in range(4,10):
    cross = cross_val_score(gbc,x,y,cv=j)
    lsc = cross.mean()
    print("At cv:-",j)
    print('Cross validation score is:-',lsc*100)
    print('accuracy_score is:-',accu*100)
    print('\n')
# Out:
# At cv:- 4
# Cross validation score is:- 85.3575157814799
# accuracy_score is:- 97.80281690140845
#
#
# At cv:- 5
# Cross validation score is:- 83.39374535116659
# accuracy_score is:- 97.80281690140845
#
#
# At cv:- 6
# Cross validation score is:- 89.76916643396463
# accuracy_score is:- 97.80281690140845
#
#
# At cv:- 7
# Cross validation score is:- 89.22457156975908
# accuracy_score is:- 97.80281690140845
#
#
# At cv:- 8
# Cross validation score is:- 89.48259942922624
# accuracy_score is:- 97.80281690140845
#
#
# At cv:- 9
# Cross validation score is:- 90.11301591993237
# accuracy_score is:- 97.80281690140845

# %%
lsscore_selected = cross_val_score(gbc,x,y,cv=9).mean()
print("The cv score is: ",lsscore_selected,"\nThe accuracy score is: ",accu)
# Out:
# The cv score is:  0.9014503641304794
# The accuracy score is:  0.9780281690140845

# %% [markdown]
# # SVC

# %% [markdown]
# # Finding Best Random State

# %%
from sklearn.svm import SVC

# %%
x_train, x_test, y_train, y_test = train_test_split(smt_x, smt_y, test_size=0.3, random_state=126)

# %%
svc = SVC()
svc.fit(x_train,y_train)

metric_score(svc,x_train,x_test,y_train, y_test, train=True)

metric_score(svc,x_train,x_test,y_train, y_test, train=False)
# Out:
# ========================== Train Result=============================
# Accuracy Score: 94.75%
#
# ==========================Test Result=======================
# Accuracy Score: 93.13%
#
#
#  Test Classification Report
#                precision    recall  f1-score   support
#
#            1       0.99      0.96      0.97      1295
#            2       0.93      0.91      0.92      1349
#            3       0.88      0.90      0.89      1316
#            4       0.93      0.96      0.94      1365
#
#     accuracy                           0.93      5325
#    macro avg       0.93      0.93      0.93      5325
# weighted avg       0.93      0.93      0.93      5325
#
#
#  Confusion Matrix:
#  [[1239   50    6    0]
#  [  10 1226  106    7]
#  [   3   34 1186   93]
#  [   0    4   53 1308]]

# %% [markdown]
# # Cross - Validation for SVC

# %%
pred_svc = svc.predict(x_test)
accu = accuracy_score(y_test,pred_svc)

# %%
for j in range(4,10):
    cross = cross_val_score(svc,x,y,cv=j)
    lsc = cross.mean()
    print("At cv:-",j)
    print('Cross validation score is:-',lsc*100)
    print('accuracy_score is:-',accu*100)
    print('\n')
# Out:
# At cv:- 4
# Cross validation score is:- 84.23531017134178
# accuracy_score is:- 93.12676056338029
#
#
# At cv:- 5
# Cross validation score is:- 84.98363496561575
# accuracy_score is:- 93.12676056338029
#
#
# At cv:- 6
# Cross validation score is:- 84.90925989804913
# accuracy_score is:- 93.12676056338029
#
#
# At cv:- 7
# Cross validation score is:- 84.18341393327225
# accuracy_score is:- 93.12676056338029
#
#
# At cv:- 8
# Cross validation score is:- 83.88527593480624
# accuracy_score is:- 93.12676056338029
#
#
# At cv:- 9
# Cross validation score is:- 83.72585121144199
# accuracy_score is:- 93.12676056338029

# %%
lsscore_selected = cross_val_score(svc,x,y,cv=5).mean()
print("The cv score is: ",lsscore_selected,"\nThe accuracy score is: ",accu)
# Out:
# The cv score is:  0.8498363496561575
# The accuracy score is:  0.9312676056338028

# %% [markdown]
# # KNN

# %% [markdown]
# # Finding Random State

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
# finding Best Random state
maxAccu=0
maxRS=0

for i in range(1, 200):
    x_train, x_test, y_train, y_test = train_test_split(smt_x, smt_y, test_size=0.3, random_state=i)
    knn=KNeighborsClassifier()
    knn.fit(x_train, y_train)
    pred = knn.predict(x_test)
    accuracy = accuracy_score(y_test, pred)
    
    if accuracy>maxAccu:
        maxAccu=accuracy
        maxRS=i

print("Best Accuracy score is", maxAccu,"on Random State", maxRS)
# Out:
# Best Accuracy score is 0.8694835680751174 on Random State 58

# %%
x_train, x_test, y_train, y_test = train_test_split(smt_x, smt_y, test_size=0.3, random_state=40)

# %%
knn = KNeighborsClassifier()
knn.fit(x_train,y_train)

metric_score(knn,x_train,x_test,y_train, y_test, train=True)

metric_score(knn,x_train,x_test,y_train, y_test, train=False)
# Out:
# ========================== Train Result=============================
# Accuracy Score: 91.14%
#
# ==========================Test Result=======================
# Accuracy Score: 85.48%
#
#
#  Test Classification Report
#                precision    recall  f1-score   support
#
#            1       0.88      0.82      0.85      1335
#            2       0.75      0.76      0.75      1295
#            3       0.86      0.85      0.86      1376
#            4       0.92      0.99      0.95      1319
#
#     accuracy                           0.85      5325
#    macro avg       0.85      0.85      0.85      5325
# weighted avg       0.85      0.85      0.85      5325
#
#
#  Confusion Matrix:
#  [[1098  221   11    5]
#  [ 140  979  158   18]
#  [   5  102 1175   94]
#  [   0    1   18 1300]]

# %% [markdown]
# # Cross - Validation for KNN

# %%
pred_knn = knn.predict(x_test)
accu = accuracy_score(y_test,pred_knn)

# %%
for j in range(4,10):
    cross = cross_val_score(knn,x,y,cv=j)
    lsc = cross.mean()
    print("At cv:-",j)
    print('Cross validation score is:-',lsc*100)
    print('accuracy_score is:-',accu*100)
    print('\n')
# Out:
# At cv:- 4
# Cross validation score is:- 65.38247498147113
# accuracy_score is:- 85.48356807511736
#
#
# At cv:- 5
# Cross validation score is:- 63.642580575976204
# accuracy_score is:- 85.48356807511736
#
#
# At cv:- 6
# Cross validation score is:- 62.61790464144724
# accuracy_score is:- 85.48356807511736
#
#
# At cv:- 7
# Cross validation score is:- 64.0816550130958
# accuracy_score is:- 85.48356807511736
#
#
# At cv:- 8
# Cross validation score is:- 64.78721890122404
# accuracy_score is:- 85.48356807511736
#
#
# At cv:- 9
# Cross validation score is:- 64.08255129436687
# accuracy_score is:- 85.48356807511736

# %%
lsscore_selected = cross_val_score(knn,x,y,cv=8).mean()
print("The cv score is: ",lsscore_selected,"\nThe accuracy score is: ",accu)
# Out:
# The cv score is:  0.6478721890122403
# The accuracy score is:  0.8548356807511737

# %% [markdown]
# # Selecting Best Model

# %% [markdown]
# # Based on comparing Accuracy Score results with Cross Validation results, it is determined Gradient Boosting Classifier is the best model. It has least difference between accuracy score and cross validation.

# %% [markdown]
# # Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# %%
x_train, x_test, y_train, y_test = train_test_split(smt_x, smt_y, test_size=0.3, random_state=592)

# %%
param = {
    'max_depth': range(4,8),
    'min_samples_split': range(2,8,2),
    'learning_rate': np.arange(0.1,0.3),
    'n_estimators':[150,200,250],
    'min_samples_leaf':[2,3,4,5]
}

# %%
gbc=GradientBoostingClassifier()

# %%
gbc=GradientBoostingClassifier(max_depth=6 , min_samples_split=4, min_samples_leaf=5, learning_rate=0.1, n_estimators=200)
gbc.fit(x_train,y_train)

metric_score(gbc,x_train,x_test,y_train, y_test, train=True)

metric_score(gbc,x_train,x_test,y_train, y_test, train=False)
# Out:
# ========================== Train Result=============================
# Accuracy Score: 100.00%
#
# ==========================Test Result=======================
# Accuracy Score: 98.95%
#
#
#  Test Classification Report
#                precision    recall  f1-score   support
#
#            1       0.99      1.00      1.00      1306
#            2       1.00      0.98      0.99      1360
#            3       0.98      0.99      0.98      1305
#            4       0.99      0.99      0.99      1354
#
#     accuracy                           0.99      5325
#    macro avg       0.99      0.99      0.99      5325
# weighted avg       0.99      0.99      0.99      5325
#
#
#  Confusion Matrix:
#  [[1306    0    0    0]
#  [   9 1337   13    1]
#  [   1    6 1292    6]
#  [   0    0   20 1334]]

# %% [markdown]
# # ROC_AUC Curve

# %%
from sklearn.metrics import roc_curve, auc

# %%
#predicting the data
y_pred_cnb = gbc.predict(x_test)
y_prob_pred_cnb = gbc.predict_proba(x_test)

# %%
# roc curve for classes
fpr = {}
tpr = {}
thresh ={}

n_class = 4

for i in range(n_class):    
    fpr[i], tpr[i], thresh[i] = roc_curve(y_test, y_prob_pred_cnb[:,i], pos_label=i)
    
# plotting    
plt.plot(fpr[0], tpr[0], linestyle='--', label='Class 1 vs Rest')
plt.plot(fpr[1], tpr[1], linestyle='--', label='Class 2 vs Rest')
plt.plot(fpr[2], tpr[2], linestyle='--', label='Class 3 vs Rest')
plt.plot(fpr[3], tpr[3], linestyle='--', label='Class 4 vs Rest')


plt.title('Multiclass ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')
plt.legend(loc='best')

# %% [markdown]
# # Model Save

# %%
import pickle
pickle.dump(gbc, open('Insurance_claims_Final','wb'))

# %% [markdown]
# # Predicting the Price range

# %%
print(gbc.predict(x))
# Out:
# [3 3 4 ... 4 4 2]

# %%
Prediction_accuracy = pd.DataFrame({'Predictions': gbc.predict(x), 'Actual Values': y})
Prediction_accuracy.head(10)
# Out:
#    Predictions  Actual Values
# 0            3              3
# 1            3              3
# 2            4              4
# 3            4              4
# 4            4              4
# 5            3              3
# 6            4              4
# 7            4              4
# 8            4              4
# 9            3              3

# %% [markdown]
# # Conclusion

# %% [markdown]
# We have successfully analysed the Zomato Restaurant dataset and performed the Data EDA, Data Pre-processing and cleaning, finding the relationships between the different variable columns in the dataset. We also trained our model using the Random Forest algorithms and obtained a very high accuracy on the test dataset in predicting the fraudulent activities in the dataset. And then finally saved the model in pickle file.
